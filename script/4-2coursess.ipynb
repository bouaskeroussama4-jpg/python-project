# %%
x = 2

# %%
x
# Out:
# 2

# %%
print(x)
# Out:
# 2

# %%
type(x)
# Out:
# int

# %%
y = 5.678

# %%
type(y)
# Out:
# float

# %%
z='TUNISIA'

# %%
type(z)
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
x+4
# Out:
# 6

# %%
x+y
# Out:
# 7.678

# %%
x=x+4

# %%
print(x)
# Out:
# 6

# %%
x == y
# Out:
# False

# %%
sum1 = 100 + 50

# %%
print(sum1)
# Out:
# 150
