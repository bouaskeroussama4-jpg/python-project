# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\bouas\instacart bascket analysis'

# %%
Deriving_New_Variables= pd.read_pickle(os.path.join(path, 'data', 'prepared_data', 'Deriving New Variables.pkl'))

# %%
df= Deriving_New_Variables

# %%
df = Deriving_New_Variables[:1000000]

# %%
df.shape
# Out:
# (1000000, 20)

# %%
df.groupby('product_name')

# %%
df.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id eval_set  order_number  order_dow  \
# 0             19     5.8      1107    38259    prior             2          1
# 1             19     5.8      5319   196224    prior            65          1
# 2             19     5.8      7540   138499    prior             8          0
# 3             19     5.8      9228    79603    prior             2          2
# 4             19     5.8      9273    50005    prior             1          1
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %%
# If order_number is a column in a DataFrame df
df['order_number'].value_counts()
# Out:
# order_number
# 1     66241
# 2     64997
# 3     64415
# 4     57293
# 5     51452
#       ...
# 96      438
# 95      425
# 97      420
# 98      387
# 99      357
# Name: count, Length: 99, dtype: int64

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.577493
# 2                17.320781
# 3                16.084944
# 4                17.530458
# 5                14.763075
# 6                16.658449
# 7                17.031590
# 8                15.076662
# 9                15.447580
# 10               18.681852
# 11               15.467644
# 12               14.327957
# 13               16.548642
# 14               16.960241
# 15               16.121948
# 16               17.801107
# 17               15.593633
# 18               19.674252
# 19               16.899756
# 20               16.255442
# 21               25.535479

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.577493
# 2     17.320781
# 3     16.084944
# 4     17.530458
# 5     14.763075
# 6     16.658449
# 7     17.031590
# 8     15.076662
# 9     15.447580
# 10    18.681852
# 11    15.467644
# 12    14.327957
# 13    16.548642
# 14    16.960241
# 15    16.121948
# 16    17.801107
# 17    15.593633
# 18    19.674252
# 19    16.899756
# 20    16.255442
# 21    25.535479
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.577493   1  99
# 2                17.320781   1  96
# 3                16.084944   1  99
# 4                17.530458   1  99
# 5                14.763075   1  99
# 6                16.658449   1  99
# 7                17.031590   1  99
# 8                15.076662   1  98
# 9                15.447580   1  99
# 10               18.681852   1  99
# 11               15.467644   1  99
# 12               14.327957   1  99
# 13               16.548642   1  99
# 14               16.960241   1  99
# 15               16.121948   1  99
# 16               17.801107   1  99
# 17               15.593633   1  99
# 18               19.674252   1  99
# 19               16.899756   1  99
# 20               16.255442   1  99
# 21               25.535479   1  98

# %%
Deriving_New_Variables['max_order'] = Deriving_New_Variables.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\bouas\AppData\Local\Temp\ipykernel_78748\921773516.py:1: FutureWarning: The provided callable <function max at 0x000002A5129CF100> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   Deriving_New_Variables['max_order'] = Deriving_New_Variables.groupby(['user_id'])['order_number'].transform(np.max)

# %%
Deriving_New_Variables.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id eval_set  order_number  ...  \
# 0             19     5.8      1107    38259    prior             2  ...
# 1             19     5.8      5319   196224    prior            65  ...
# 2             19     5.8      7540   138499    prior             8  ...
# 3             19     5.8      9228    79603    prior             2  ...
# 4             19     5.8      9273    50005    prior             1  ...
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %%
user_id = 1
Deriving_New_Variables[Deriving_New_Variables['user_id'] == user_id][['user_id', 'order_number', 'max_order']]
# Out:
#           user_id  order_number  max_order
# 96915           1             5         10
# 97411           1             3         10
# 98186           1             7         10
# 115917          1             4         10
# 116323          1             9         10
# 117387          1             2         10
# 118800          1             1         10
# 118930          1            10         10
# 124876          1             8         10
# 127601          1             6         10
# 5972029         1             5         10
# 5972051         1             3         10
# 5972102         1             7         10
# 5973035         1             4         10
# 5973051         1             9         10
# 5973109         1             2         10
# 5973193         1            10         10
# 5973533         1             8         10
# 5973677         1             6         10
# 6003496         1             5         10
# 7158144         1             5         10
# ...

# %%
Deriving_New_Variables.loc[Deriving_New_Variables['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
Deriving_New_Variables.loc[(Deriving_New_Variables['max_order'] <= 40) & (Deriving_New_Variables['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
Deriving_New_Variables.loc[Deriving_New_Variables['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
Deriving_New_Variables.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id eval_set  order_number  ...  \
# 0             19     5.8      1107    38259    prior             2  ...
# 1             19     5.8      5319   196224    prior            65  ...
# 2             19     5.8      7540   138499    prior             8  ...
# 3             19     5.8      9228    79603    prior             2  ...
# 4             19     5.8      9273    50005    prior             1  ...
#
#    days_since_prior_order  add_to_cart_order  reordered  _merge  \
# 0                     7.0                7.0        0.0    both
# ...

# %%
Deriving_New_Variables['loyalty_flag'].value_counts()
# Out:
# loyalty_flag
# Regular customer    15877395
# Loyal customer      10284396
# New customer         6244250
# Name: count, dtype: int64

# %%
Deriving_New_Variables[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0     38259      New customer             2
# 1    196224    Loyal customer            65
# 2    138499  Regular customer             8
# 3     79603      New customer             2
# 4     50005  Regular customer             1
# 5    108919    Loyal customer            46
# 6     63782      New customer             4
# 7    170451      New customer             5
# 8    106854    Loyal customer            28
# 9    181127  Regular customer            10
# 10   106519  Regular customer            18
# 11   145505    Loyal customer            64
# 12   139923  Regular customer            16
# 13   110984  Regular customer             2
# 14   180719    Loyal customer            84
# 15   142388  Regular customer             7
# 16   200356  Regular customer            11
# 17     4122  Regular customer            11
# 18   162394      New customer             2
# 19   148255  Regular customer            18
# ...
