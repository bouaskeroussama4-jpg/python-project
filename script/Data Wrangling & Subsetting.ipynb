# %% [markdown]
# # Data wrangling and Subsetting

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# creating path
path = r'C:\Users\bouas\instacart bascket analysis'

# %%
df_ords = pd.read_csv(os.path.join(path, 'data', 'original_data', 'orders.csv'))

# %%
df_prods = pd.read_csv(os.path.join(path, 'data', 'original_data', 'products.csv'), index_col = False)

# %%
# importing df-products
df_prods = pd.read_csv(os.path.join(path, 'data', 'original_data', 'products.csv'), index_col = False)

# %%
df_dep = pd.read_csv(os.path.join(path, 'data', 'original_data', 'departments.csv'), index_col = False)

# %%
# drop eval set
df_ords.drop(columns = ['eval_set'])
# Out:
#         order_id user_id  order_number  order_dow  order_hour_of_day  \
# 0        2539329       1             1          2                  8
# 1        2398795       1             2          3                  7
# 2         473747       1             3          3                 12
# 3        2254736       1             4          4                  7
# 4         431534       1             5          4                 15
# ...          ...     ...           ...        ...                ...
# 3421078  2266710  206209            10          5                 18
# 3421079  1854736  206209            11          4                 10
# 3421080   626363  206209            12          1                 12
# 3421081  2977660  206209            13          1                 12
# 3421082   272231  206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# 2                          21.0
# ...

# %%
df_ords_2 = df_ords.drop(columns = ['eval_set'])

# %%
# not displaying order id 
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
df_dep_t=df_dep.T

# %%
# new header
new_header = df_dep_t.iloc[0]

# %%
df_dep_t_1 = df_dep_t[1:]

# %%
#  new header
df_dep_t_1.columns = new_header

# %%
df_dep_t_1
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
data_dict = df_dep_t_1.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %% [markdown]
# ## 2/Find another identifier variable in the df_ords dataframe that doesn’t need to be included in your analysis as a numeric variable and change it to a suitable format.

# %%
# not displayeing Order number
df_ords_2['order_number'] = df_ords_2['order_number'].astype('str')

# %%
df_ords.dtypes
# Out:
# order_id                   object
# user_id                    object
# eval_set                   object
# order_number               object
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
# changing the name order dow to orders day of the week
df_ords_2.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %% [markdown]
# ## 3/Look for a variable in your df_ords dataframe with an unintuitive name and change its name without overwriting the dataframe.

# %%
# changing the name to days since last order
df_ords_2.rename(columns = {'days_since_prior_order' : 'days_since_last_order'}, inplace = True)

# %%
df_ords_2.head()
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_last_order
# 0                    NaN
# 1                   15.0
# 2                   21.0
# 3                   29.0
# 4                   28.0

# %% [markdown]
# ## 5/Your client wants to know what the busiest hour is for placing orders. Find the frequency of the corresponding variable and share your findings.

# %%
# Here we should determine when ,so we need to have the count of the  orders hours of day 
df_ords_2['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %% [markdown]
# #### At 10 a.m., the highest number of orders are observed wich is the busiest hour for placing orders(288418)

# %% [markdown]
# ## 5/Determine the meaning behind a value of 4 in the "department_id" column within the df_prods dataframe using a data dictionary

# %%
# importing df-products
df_prods = pd.read_csv(os.path.join(path, 'data', 'original_data', 'products.csv'), index_col = False)

# %%
# using the fonction  : print(data_dict.get('4')) in our data dictionary

# %% [markdown]
# ### we will get {'department': 'produce'}

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# ## 6/The sales team in your client’s organization wants to know more about breakfast item sales.

# %% [markdown]
# ### searching in data dict: 14': {'department': 'breakfast'},

# %%
# processing to get item sales...
df_breakfast = df_prods.loc[df_prods['department_id'] == 14]

# %%
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %% [markdown]
# ## 7/items from the following departments: alcohol, deli, beverages, and meat/seafood. You’ll need to present this subset to your client.

# %%
# dinner partie list form data dictionnary : 
# 1 frozen : to prepare rapidly  the dinner  so that s why it can be from dinner partie
# 12 meat seafood, 5 alkhool ,  20 deli , 7 beverages

# %%
df_dinner_parties= df_prods.loc[df_prods['department_id'].isin([1,12,5,20,7])]

# %%
df_dinner_parties
# Out:
#        product_id                                       product_name  \
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 6               7                     Pure Coconut Water With Orange
# 7               8                  Cut Russet Potatoes Steam N' Mash
# 9              10     Sparkling Orange Juice & Prickly Pear Beverage
# ...           ...                                                ...
# 49682       49678                    Large Chicken & Cheese Taquitos
# 49685       49681            Spaghetti with Meatballs and Sauce Meal
# 49686       49682                                 California Limeade
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
#
#        aisle_id  department_id  prices
# 2            94              7     4.5
# 3            38              1    10.5
# ...

# %% [markdown]
# ## 8/It’s important that you keep track of total counts in your dataframes. How many rows does the last dataframe you created have?

# %% [markdown]
# ### 11657 rows × 5 columns

# %% [markdown]
# ### 9/Someone from the data engineers team in Instacart thinks they’ve spotted something strange about the customer with a "user_id" of “1.” Extract all the information you can about this user.

# %%
df_USER1=df_ords_2.loc[df_ords_2['user_id'] == '1']

# %%
df_USER1
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2398795       1             2                   3                  7
# 2    473747       1             3                   3                 12
# 3   2254736       1             4                   4                  7
# 4    431534       1             5                   4                 15
# 5   3367565       1             6                   2                  7
# 6    550135       1             7                   1                  9
# 7   3108588       1             8                   1                 14
# 8   2295261       1             9                   1                 16
# 9   2550362       1            10                   4                  8
# 10  1187899       1            11                   4                  8
#
#     days_since_last_order
# 0                     NaN
# 1                    15.0
# ...

# %% [markdown]
# ##  10/You also need to provide some details about this user’s behavior. What basic stats can you provide based on the information you have?

# %%
df_USER1.describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count     11.000000           11.000000          11.000000
# mean       6.000000            2.636364          10.090909
# std        3.316625            1.286291           3.477198
# min        1.000000            1.000000           7.000000
# 25%        3.500000            1.500000           7.500000
# 50%        6.000000            3.000000           8.000000
# 75%        8.500000            4.000000          13.000000
# max       11.000000            4.000000          16.000000
#
#        days_since_last_order
# count              10.000000
# mean               19.000000
# std                 9.030811
# min                 0.000000
# 25%                14.250000
# 50%                19.500000
# 75%                26.250000
# max                30.000000

# %% [markdown]
# ## 11/Export your df_ords dataframe as “orders_wrangled.csv” in your “Prepared Data” folder

# %%
df_ords.to_csv(os.path.join(path, 'data','prepared_data', 'orders_wrangled.csv'))

# %% [markdown]
# ## 12/Export the df_dep_t_new dataframe as “departments_wrangled.csv” in your “Prepared Data” folder so that you have a “.csv” file of your departments data in the correct format.

# %%
df_dep.to_csv(os.path.join(path, 'data','prepared_data', 'departments_wrangled.csv'))
