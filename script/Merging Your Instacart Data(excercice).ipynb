# %% [markdown]
# # Exercice Merging Your Instacart Data

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\bouas\instacart bascket analysis'

df_ords_prior= pd.read_csv(os.path.join(path, 'data', 'original_data', 'orders_products_prior.csv'), index_col = False)

df = pd.read_csv(os.path.join(path, 'data', 'original_data', 'orders.csv'), index_col = False)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df.shape
# Out:
# (3421083, 7)

# %% [markdown]
# # Merging Your Instacart Data

# %%
df_merged_large = df.merge(df_ords_prior, on = 'order_id', indicator =True)

# %%
df_merged_large
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32434484   2977660   206209    prior            13          1
# 32434485   2977660   206209    prior            13          1
# 32434486   2977660   206209    prior            13          1
# 32434487   2977660   206209    prior            13          1
# 32434488   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged_large = df.merge(df_ords_prior, on = 'order_id', indicator = True, how='outer')

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only       206209
# right_only           0
# Name: count, dtype: int64

# %%
# Export data to csv

df_merged_large.to_csv(os.path.join(path, 'data','prepared_data', 'orders_products_combined.csv'))

# Export data to pkl

df_merged_large.to_pickle(os.path.join(path, 'data','prepared_data', 'orders_products_combined.pkl'))
