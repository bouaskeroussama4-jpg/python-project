# %% [markdown]
# # Importing libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Python data type

# %% [markdown]
# # Code 3 different ways of reaching a result of 100 by adding or subtracting numeric variables.

# %%
# first method
A = 90
B= 10
print (A + B)
# Out:
# 100

# %%
# second method
A = 800
B = 700
print (A-B)
# Out:
# 100

# %%
# third method
A= 200
B= 100
C=500
D=700
print (A+B+C-D)
# Out:
# 100

# %% [markdown]
# # Code 2 floating-point variables and divide them by each other.

# %%
# the first V
x= 5.155
y=1.487
print (x/y)
# Out:
# 3.4667114996637522

# %%
# The second V
x=87.14
z=87.12
print (x/z)
# Out:
# 1.0002295684113864

# %% [markdown]
# # Construct a short word made of separate strings (you’ll need to concatenate some strings!)

# %%
x='DA'
y='TA'
print (x+y)
# Out:
# DATA

# %% [markdown]
# # Construct 2 short sentences made of separate strings.

# %%
x = 'HELLO,'
y = ' CF!!'
print (x+y)
# Out:
# HELLO, CF!!

# %% [markdown]
# # At the bottom of your file, include a command that makes a string appear 100 times

# %%
x='CAREER_FOUNDRY'
print (x*100)
# Out:
# CAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRYCAREER_FOUNDRY
